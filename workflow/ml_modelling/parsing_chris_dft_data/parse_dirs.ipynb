# %% [markdown]
# # Parsing Chris's DFT Data on NERSC
# ---
#
#
# Author(s): Raul A. Flores

# %% [markdown]
# # Notes
# ---

# %% [raw]
# ID IrO3-146 isn't availabe in the parsed folders
#
# -171.82382373
# Ir8O24

# %% [markdown]
# # Import Modules

# %%
import os
import sys

sys.path.insert(0, os.path.join(
    os.environ["PROJ_irox"],
    "chris_prototypes_structures/oqmd_iro3",
    ))

sys.path.insert(0, os.path.join(
    os.environ["PROJ_irox"],
    "data",
    ))

import csv
import pickle

import numpy as np
import pandas as pd

from ase import io
from ase.visualize import view

import plotly.plotly as py
import plotly.graph_objs as go

# #############################################################################
# #############################################################################
from IPython.display import display

# %% [markdown]
# # Script Inputs

# %%
root_dir = "/mnt/f/GDrive/norskov_research_storage/00_projects/PROJ_irox_2/chris_nersc_files"

# Sandbox
mu_O = -4.523295 + 0.5
mu_Ir = -10.25489552061731 - 0.1

# From Pourbaix Scripts
# mu_O = -4.18119602
# mu_Ir = -8.860644725

# OQMD references
# mu_O = -4.523295
# mu_Ir = -8.855

# %% [markdown]
# # Parse ID List from Files from Chris

# %%
file_path_i = os.path.join(
    os.environ["PROJ_irox"],
    "data/ml_irox_data/iro2_training_data.csv")
train_data_iro2 = pd.read_csv(file_path_i)
train_data_iro2.set_index("id", inplace=True)

file_path_i = os.path.join(
    os.environ["PROJ_irox"],
    "data/ml_irox_data/iro3_training_data.csv")
train_data_iro3 = pd.read_csv(file_path_i)
train_data_iro3.set_index("id", inplace=True)

train_data_dict = {
    "iro2": train_data_iro2,
    "iro3": train_data_iro3,
    }

# %% [markdown]
# # Parse NERSC DFT Data
#
# Comment out to read pickled data file instead (saves time)

# %%
# master_data_list = []

# id_list_nersc = []
# for subdir, dirs, files in os.walk(root_dir):
#     if "gas_references" in subdir:
#         continue
#     if "IrO2/Old_ML_calcs" in subdir:
#         continue
#     if "__old__" in subdir:
#         continue
#     if "volume" in subdir:
#         continue
        
#     if "OUTCAR" in files:
#         print(subdir[81:])

#         dir_i = subdir

#         id_i = int(subdir.split("/")[-1].split("_")[0])

#         try:
#             atoms_i = io.read(os.path.join(dir_i, "OUTCAR"))
#             energy_i = atoms_i.get_potential_energy()
#         except:
#             atoms_i = None

#         path_short_i = dir_i.replace("/mnt/f/GDrive/norskov_research_storage/00_projects/PROJ_irox_2/chris_nersc_files/", "")

#         dict_i = {
#             "id": id_i,
#             "atoms": atoms_i,
#             "energy": energy_i,
#             "path": path_short_i,
#             }

#         master_data_list.append(dict_i)

# directory = "out_data"
# if not os.path.exists(directory):
#     os.makedirs(directory)
# # Save Data
# with open("parse_data.pickle", "wb") as fle:
#     pickle.dump(master_data_list, fle)

# %%
with open("out_data/parse_data.pickle", "rb") as fle:
    master_data_list = pickle.load(fle)

df = pd.DataFrame(master_data_list)

# %% [markdown]
# # Process dataframe

# %%
def method(row_i):
    """
    """
    if "IrO2" in row_i["path"]:
        sys_i = "AB2"
    elif "IrO3" in row_i["path"]:
        sys_i = "AB3"
    else:
        sys_i = None
    return(sys_i)

df["stoich"] = df.apply(
    method,
    axis=1,
    )

# #############################################################################
# #############################################################################

def method(row_i):
    """
    """
    ignore_list = [
        "IrO3/winnersIrO3",
        "IrO3/full_relax",
        "IrO3/full_relax_ML1",
        "IrO3/full_relax_ML2",
        "IrO3/full_relax_ML3",
        "IrO3/full_relax_ML4",
        "IrO3/single_point",
        "IrO3/volume_relax",
        "IrO3/volume_relax_ML1",
        "IrO3/volume_relax_ML2",
        "IrO3/volume_relax_ML3",
        "IrO3/volume_relax_ML4",
        ]
    ignore = False
    for ignore_seg_i in ignore_list:
        if ignore_seg_i in row_i["path"]:
            ignore = True

    return(ignore)

# #############################################################################
# #############################################################################

df["ignore_tag"] = df.apply(
    method,
    axis=1,
    )

def method(row_i):
    """
    """
    if "volume" in row_i["path"]:
        out = True
    else:
        out = False
    return(out)

df["volume_tag"] = df.apply(
    method,
    axis=1,
    )

# #############################################################################
# #############################################################################

def method(row_i):
    """
    """    
    atoms_i = row_i["atoms"]
    
    if atoms_i is None:
        return(None)
    else:
        num_atoms_i = len(atoms_i.get_atomic_numbers())
        energy_norm_i = row_i["energy"] / num_atoms_i

        return(energy_norm_i)

df["energy_pa"] = df.apply(
    method,
    axis=1,
    )



def method(row_i):
    """
    """    
    atoms_i = row_i["atoms"]

    if atoms_i is not None:
        forces = atoms_i.get_forces()
        forces_sum = 0.0
        forces_largest = 0.0
        for a in range(len(atoms_i)):
            force_i = np.sqrt(forces[a][0] ** 2 + forces[a][1] ** 2 + forces[a][2] ** 2)
            forces_sum += force_i
            if(force_i > forces_largest):
                forces_largest = force_i

        row_i["force_max"] = forces_largest
        row_i["force_sum"] = forces_sum
    else:
        row_i["force_max"] = None
        row_i["force_sum"] = None

    return(row_i)


df = df.apply(
    method,
    axis=1,
    )

# def method(row_i):
#     """
#     """    
#     energy_per_atom_i = row_i["energy_per_atom"]
#     stoich_i = row_i["stoich"]

#     if stoich_i == "AB2":
#         form_e_i = (3 * energy_per_atom_i) - (1. * mu_Ir) - (2. * mu_O)
#         form_e_i = form_e_i / 3
#     elif stoich_i == "AB3":
#         form_e_i = (4 * energy_per_atom_i) - (1. * mu_Ir) - (3. * mu_O)
#         form_e_i = form_e_i / 4
#     else:
#         form_e_i = None

# #     print(form_e_i)

#     return(form_e_i)

# df["form_e"] = df.apply(
#     method,
#     axis=1,
#     )

# #############################################################################
# #############################################################################

# %%
print("Number of calculations for IrO3 parsed:", len(df[df["stoich"] == "IrO3"]))

df = df[df["ignore_tag"] == False]
df = df[df["volume_tag"] == False]

# df = df[df["force_max"] < 0.01]
# df = df[df["force_max"] < 0.05]
# Out:
# Number of calculations for IrO3 parsed: 0

# %% [markdown]
# # IrO2

# %%
# df_iro2 = df[df["stoich"] == "IrO2"]
df_iro2 = df[df["stoich"] == "AB2"]

master_data = []
for id_i, row_i in train_data_dict["iro2"].iterrows():

    if row_i["source"] != "chris":
        continue

    form_e_chris_i = row_i["form_e_chris"]

    df_i = df_iro2[df_iro2["id"] == id_i]
#     display(df_i)

    if len(df_i) == 0:
        print(id_i, " | There are no rows for this id!!!!")

    df_0 = df_i[df_i["path"].str.contains("final_opt_new1-3")]
    df_1 = df_i[df_i["path"].str.contains("final_relax")]

    row_i = None
    if len(df_0) > 0:
        if len(df_0) > 1:
            print("NOOOOOOOOOO!!!!!!!!!")
        row_j = df_0.iloc[0]

    else:
        if len(df_1) > 0:
            if len(df_1) > 1:
                print("NOOOOOOOOOO!!!!!!!!!")
            row_j = df_1.iloc[0]
        else:
            tmp = 42
    
    row_j["form_e_chris"] = form_e_chris_i
    master_data.append(row_j)

df_iro2_unique = pd.concat(master_data, axis=1, sort=True).transpose()
df_iro2_unique.set_index("id", inplace=True)
# Out:
# /home/raul_surface/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/raul_surface/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/series.py:1015: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # IrO3

# %%
# df_iro3 = df[df["stoich"] == "IrO3"]
df_iro3 = df[df["stoich"] == "AB3"]

master_data = []
for id_i, row_i in train_data_dict["iro3"].iterrows():

    if row_i["source"] != "chris":
        continue

    form_e_chris_i = row_i["form_e_chris"]

    df_i = df_iro3[df_iro3["id"] == id_i]

    if len(df_i) == 0:
        print(id_i, " | There are no rows for this id!!!!")
        row_j = pd.Series({"id": int(id_i)})
    else:
        df_0 = df_i[df_i["path"].str.contains("final_opt_new1-3_sorted")]
        if len(df_0) > 0:
            if len(df_0) > 1:
                print("NOOOOOOOOOO!!!!!!!!!")
            row_j = df_0.iloc[0]
        else:
            row_j = df_i.iloc[0]

    row_j["form_e_chris"] = form_e_chris_i
    master_data.append(row_j)

df_iro3_unique = pd.concat(master_data, axis=1, sort=True).transpose()
df_iro3_unique = df_iro3_unique.astype({"id": int})
df_iro3_unique.set_index("id", inplace=True)
# Out:
# /home/raul_surface/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Applying unique IDs

# %%
df_iro2_dft = df_iro2_unique
df_iro3_dft = df_iro3_unique

# %%
path_i = os.path.join(
    os.environ["PROJ_irox"],
    "data/ml_irox_data",
    "unique_ids.csv")

df_id = pd.read_csv(path_i)

id_mapp_iro2 = dict(zip(
    df_id[df_id["stoich"] == "AB2"]["id"],
    df_id[df_id["stoich"] == "AB2"]["unique_ids"],
    ))

id_mapp_iro3 = dict(zip(
    df_id[df_id["stoich"] == "AB3"]["id"],
    df_id[df_id["stoich"] == "AB3"]["unique_ids"],
    ))

# %%
def method(row_i):
    """
    """
    id_i = row_i.name
    if row_i["stoich"] == "IrO2" or row_i["stoich"] == "AB2":
        mapping_dict = id_mapp_iro2
    elif row_i["stoich"] == "IrO3" or row_i["stoich"] == "AB3":
        mapping_dict = id_mapp_iro3
    else:
        print(row_i)

    id_unique_i = mapping_dict[id_i]

    return(id_unique_i)

df = df_iro2_dft
df["id_unique"] = df.apply(
    method,
    axis=1,
    )
df["id_old"] =  df.index.values
df.set_index("id_unique", inplace=True)


df = df_iro3_dft
df["id_unique"] = df.apply(
    method,
    axis=1,
    )
df["id_old"] =  df.index.values
df.set_index("id_unique", inplace=True)

# %%
df_dft_calcs = pd.concat([
    df_iro2_dft,
    df_iro3_dft,
    ])

# %% [markdown]
# # Strip Unneeded Columns

# %%
good_bye_list = [
    "ignore_tag",
    "volume_tag",
    ]
df_dft_calcs.drop(good_bye_list, axis=1, inplace=True)

# %% [raw]
# Add `source` column

# %%
df_dft_calcs["source"] = "chris"

# %% [markdown]
# # Save data to pickle

# %%
directory = "out_data"
if not os.path.exists(directory):
    os.makedirs(directory)
with open("out_data/df_dft_calcs.pickle", "wb") as fle:
    pickle.dump(df_dft_calcs, fle)

# %%
df_dft_calcs
# Out:
#                                                         atoms   energy  \
# id_unique
# z39g648rnl  (Atom('O', [1.09528, 7.66698, 7.66698], index=... -150.762
# 82mwbwbgbl  (Atom('O', [7.23772, 7.23732, -0.0], index=0),... -157.948
# 8495vjvsc3  (Atom('O', [-0.51619, 6.36938, 1.47681], index... -59.1215
# xonhb1cgnq  (Atom('Ir', [-2e-05, -3e-05, 2.46526], index=0... -83.4011
# 8aza84xlvs  (Atom('Ir', [0.0, 0.0, -0.0], index=0), Atom('... -122.502
# vwxrnun48g  (Atom('O', [12.87719, 3.08577, 6.17657], index...  -711.04
# 9wzqvtmw6a  (Atom('O', [0.31715, 5.16398, 10.26108], index... -161.113
# c48lx363be  (Atom('Ir', [0.0, 0.0, 6e-05], index=0), Atom(... -81.2711
# 6fzy7kcrxy  (Atom('O', [4.28427, 4.28427, 4.28427], index=... -68.0632
# ckbg7d9u6u  (Atom('O', [4.36138, 1.53522, 3.26091], index=... -161.165
# mpbd6sz1z5  (Atom('O', [3.09598, 0.0, 0.84797], index=0), ... -225.438
# cant6qca6o  (Atom('O', [-2.42755, 2.61865, 7.11983], index... -38.6474
# zunqxh6g9j  (Atom('O', [-0.00533, -0.00176, 2.56449], inde... -199.176
# 9y85x1cp6e  (Atom('O', [-0.03738, -0.03219, 4.04309], inde... -157.176
# xgmkzuxf8g  (Atom('Ir', [-0.01463, 1.83136, 17.19958], ind... -122.307
# cfcivdxrc2  (Atom('O', [1.5944, 0.86871, 0.86873], index=0...  -42.271
# mlva81bg7p  (Atom('O', [0.09593, 1.22242, 4.09718], index=... -159.663
# nt6wv1n27r  (Atom('O', [0.0, 2.84259, 9.35384], index=0), ... -78.7783
# m4cacfvjvh  (Atom('O', [9.26099, 7.12706, 7.27881], index=...  -631.39
# 9uxemw7rv2  (Atom('O', [2.99902, 3.47422, 2.18869], index=... -317.304
# vsvsms92ng  (Atom('O', [3.20818, 3.20818, 3.20818], index=... -83.4014
# x2xj6wb48k  (Atom('O', [1.49642, 1.22875, 0.85793], index=... -114.168
# cr6rcena9l  (Atom('O', [1.41545, 0.0, 0.86337], index=0), ... -74.9632
# nkmd71vt9q  (Atom('Ir', [5.0029, -0.32417, 4.97783], index... -35.6116
# cung63bez1  (Atom('O', [4.25439, 1.60215, 1.70721], index=... -80.9181
# 7am4vwzi7p  (Atom('O', [1.26515, 1.26515, 3.79546], index=... -59.8226
# v1vpxgbg9s  (Atom('O', [2.73388, 4.3614, 5.00607], index=0... -199.488
# bp7ynac4my  (Atom('O', [0.23187, 2.39747, 6.07834], index=... -358.336
# b49kx4c19q  (Atom('O', [2.04014, 2.2474, 0.23914], index=0... -83.5316
# vl6uvqne6d  (Atom('O', [0.01325, 1.28218, 3.15398], index=... -316.957
# ...                                                       ...      ...
# 7h62vo74x4  (Atom('O', [0.00758, 4.15225, 2.96244], index=... -134.935
# vwbhvwmjmw  (Atom('O', [10.10731, 8.85549, 4.95154], index... -296.233
# 94vpmqvh9p  (Atom('O', [2.63386, 9.11302, 2.17296], index=...  -197.65
# bpvynr7p9w  (Atom('O', [0.00019, 1.90438, 1.90526], index=... -100.364
# nrml6dms9l  (Atom('O', [5.96024, 7.21502, 3.8205], index=0... -203.881
# 8jvfcyvk92  (Atom('O', [0.00012, 1.80806, 1.16624], index=... -44.8909
# mp7svl6j8s  (Atom('Ir', [3.24583, 9.20096, 2.96894], index... -97.9858
# 8pmqmq9r8f  (Atom('Ir', [0.0, 0.00216, 3.61993], index=0),...  -48.956
# 6s648e8s6p  (Atom('O', [2.92458, 6.61895, 11.40214], index... -308.116
# vlbdnoxlnh  (Atom('O', [-0.51406, 6.07664, 2.82477], index... -49.0508
# 7en56j64mi  (Atom('O', [5.59709, 3.76255, 0.0], index=0), ... -189.043
# 9e8jmu7hmo  (Atom('Ir', [0.0, 0.0, 0.0], index=0), Atom('I... -48.7752
# 7f8pm5mhnu  (Atom('O', [1.35124, 1.35124, 0.0], index=0), ...  -50.168
# zr9ic2zaz5  (Atom('O', [5.71491, 1.90475, 1.88365], index=... -100.364
# 9pzh8yxixe  (Atom('Ir', [4.08907, 4.56104, 4.50158], index... -98.0992
# xjxdzi73bg  (Atom('O', [1.1985, 1.87302, 3.38302], index=0... -49.0543
# 9txdvicqcf  (Atom('Ir', [2.4445, 4.23396, 3.22797], index=... -155.145
# xy6kzjninu                                               None -41.5379
# cgx3mkzhmd  (Atom('O', [0.0, 0.0, 0.0], index=0), Atom('O'... -50.2378
# nocg9ivex1  (Atom('Ir', [0.17767, 0.0, 2.90292], index=0),... -49.0477
# 6d6a8a637i  (Atom('O', [1.42721, 5.94602, 5.18535], index=... -197.458
# b5cgvsb16w  (Atom('O', [3.84937, 3.84936, 0.0], index=0), ... -103.309
# macixavwv3  (Atom('O', [2.86139, 1.5996, 7.53918], index=0... -310.506
# 8g6g9dv47g  (Atom('O', [5.80962, 6.13442, 3.55137], index=... -98.1366
# 8gnt9rnd92  (Atom('O', [-0.0, 2.59348, 3.77052], index=0),... -101.652
# vt9ynkzyna  (Atom('O', [6.22411, 0.59707, 1.26321], index=... -294.065
# b4nrnqvl8h  (Atom('O', [-0.0, 1.96194, 3.72373], index=0),... -46.6544
# 95nfmd6fce  (Atom('Ir', [-0.88035, 7.70607, 1.87727], inde... -196.277
# mkvpml8q9e  (Atom('O', [3.13701, 6.51149, 3.14035], index=... -98.1031
# bgcpc2vabf  (Atom('Ir', [1.7994, 5.39821, 1.7994], index=0...  -204.17
#
#            energy_pa    force_max   force_sum form_e_chris  \
# id_unique
# z39g648rnl  -6.28174            0           0    -0.085637
# 82mwbwbgbl  -6.58117   0.00683552    0.124672    -0.385069
# 8495vjvsc3  -6.56905   0.00917233   0.0413081    -0.372952
# xonhb1cgnq  -6.95009   0.00673923   0.0510938    -0.753994
# 8aza84xlvs  -6.80567   0.00931162    0.106901    -0.609567
# vwxrnun48g   -6.5837    0.0174474    0.880346    -0.387602
# 9wzqvtmw6a  -6.71302   0.00988006    0.128339    -0.516924
# c48lx363be  -6.77259     0.006717    0.039109    -0.576493
# 6fzy7kcrxy  -5.67194   0.00128172   0.0102537     0.524164
# ckbg7d9u6u  -6.71521   0.00705566   0.0808736    -0.519115
# mpbd6sz1z5  -6.26217     0.045491    0.777246    -0.066073
# cant6qca6o  -6.44123    0.0347996    0.115573    -0.245128
# zunqxh6g9j  -6.63919    0.0345984     0.58411    -0.443086
# 9y85x1cp6e    -6.549   0.00955793     0.16614    -0.352903
# xgmkzuxf8g  -6.79486   0.00943348   0.0793921    -0.598759
# cfcivdxrc2  -7.04517   0.00813091   0.0190356    -0.849069
# mlva81bg7p  -6.65264    0.0404793    0.660297    -0.456542
# nt6wv1n27r  -6.56486     0.009392    0.057514     -0.36876
# m4cacfvjvh  -6.57698   0.00721184    0.407031     -0.38088
# 9uxemw7rv2  -6.61049   0.00969317    0.227431    -0.414391
# vsvsms92ng  -6.95012  0.000656447  0.00525158     -0.75402
# x2xj6wb48k  -6.34269     0.007625   0.0901816    -0.146588
# cr6rcena9l  -6.24694     0.009316    0.052976    -0.050836
# nkmd71vt9q  -5.93526   0.00970997   0.0302046     0.260838
# cung63bez1  -6.74318   0.00895958   0.0773875    -0.547077
# 7am4vwzi7p  -4.98522            0           0      1.21088
# v1vpxgbg9s  -6.64961     0.032023    0.557364     -0.45351
# bp7ynac4my  -6.63585    0.0868235     1.63959    -0.439748
# b49kx4c19q  -6.96097    0.0451931    0.389787     -0.76487
# vl6uvqne6d  -6.60328   0.00745934    0.252763     -0.40718
# ...              ...          ...         ...          ...
# 7h62vo74x4  -5.62228     0.008227   0.0775782      0.38598
# vwbhvwmjmw  -6.17152    0.0428634    0.780675    -0.286017
# 94vpmqvh9p  -6.17656   0.00964364    0.164829    -0.330378
# bpvynr7p9w  -6.27277   0.00431134   0.0309112    -0.392176
# nrml6dms9l   -6.3713   0.00821363    0.143914    -0.499567
# 8jvfcyvk92  -5.61136    0.0254014    0.132971     0.268269
# mp7svl6j8s  -6.12411   0.00876242   0.0799336    -0.262468
# 8pmqmq9r8f  -6.11949    0.0956891    0.311235    -0.235805
# 6s648e8s6p  -6.41908   0.00999623    0.181071    -0.530512
# vlbdnoxlnh  -6.13135   0.00881492   0.0337481    -0.245249
# 7en56j64mi  -5.90761     0.009257    0.111191    -0.024289
# 9e8jmu7hmo   -6.0969   0.00525622   0.0210249    -0.228049
# 7f8pm5mhnu    -6.271     0.003875    0.009408    -0.395679
# zr9ic2zaz5  -6.27277   0.00619615   0.0757476    -0.392167
# 9pzh8yxixe   -6.1312    0.0143466    0.114145    -0.247327
# xjxdzi73bg  -6.13179   0.00699854   0.0358105    -0.248005
# 9txdvicqcf  -6.46439    0.0068257    0.095409     -0.59926
# xy6kzjninu       NaN          NaN         NaN    -0.265077
# cgx3mkzhmd  -6.27973   0.00650864   0.0318944    -0.399059
# nocg9ivex1  -6.13097   0.00890977   0.0470524    -0.246969
# 6d6a8a637i  -6.17056   0.00898371    0.217064    -0.294417
# b5cgvsb16w  -6.45679   0.00583339   0.0713703    -0.559365
# macixavwv3  -6.46888   0.00475744    0.150207    -0.586571
# 8g6g9dv47g  -6.13354    0.0505106    0.459223    -0.240464
# 8gnt9rnd92  -6.35327   0.00991788    0.083263    -0.482107
# vt9ynkzyna  -6.12636    0.0092623    0.158211    -0.257918
# b4nrnqvl8h   -5.8318     0.021767    0.059942     0.043482
# 95nfmd6fce  -6.13365   0.00844586    0.147468    -0.265874
# mkvpml8q9e  -6.13144    0.0708449    0.468587    -0.250202
# bgcpc2vabf  -6.38032   0.00845601    0.202944    -0.495877
#
#                                                      path stoich  id_old  \
# id_unique
# z39g648rnl             IrO2/final_opt_new1-3/25_fixed.cif    AB2      25
# 82mwbwbgbl             IrO2/final_opt_new1-3/59_fixed.cif    AB2      59
# 8495vjvsc3             IrO2/final_opt_new1-3/69_fixed.cif    AB2      69
# xonhb1cgnq             IrO2/final_opt_new1-3/72_fixed.cif    AB2      72
# 8aza84xlvs             IrO2/final_opt_new1-3/73_fixed.cif    AB2      73
# vwxrnun48g             IrO2/final_opt_new1-3/80_fixed.cif    AB2      80
# 9wzqvtmw6a             IrO2/final_opt_new1-3/83_fixed.cif    AB2      83
# c48lx363be            IrO2/final_opt_new1-3/107_fixed.cif    AB2     107
# 6fzy7kcrxy            IrO2/final_opt_new1-3/152_fixed.cif    AB2     152
# ckbg7d9u6u            IrO2/final_opt_new1-3/167_fixed.cif    AB2     167
# mpbd6sz1z5    April_Backup/IrO2/final_relax/169_fixed.cif    AB2     169
# cant6qca6o            IrO2/final_opt_new1-3/173_fixed.cif    AB2     173
# zunqxh6g9j    April_Backup/IrO2/final_relax/189_fixed.cif    AB2     189
# 9y85x1cp6e            IrO2/final_opt_new1-3/196_fixed.cif    AB2     196
# xgmkzuxf8g            IrO2/final_opt_new1-3/197_fixed.cif    AB2     197
# cfcivdxrc2            IrO2/final_opt_new1-3/199_fixed.cif    AB2     199
# mlva81bg7p    April_Backup/IrO2/final_relax/231_fixed.cif    AB2     231
# nt6wv1n27r            IrO2/final_opt_new1-3/233_fixed.cif    AB2     233
# m4cacfvjvh            IrO2/final_opt_new1-3/238_fixed.cif    AB2     238
# 9uxemw7rv2            IrO2/final_opt_new1-3/244_fixed.cif    AB2     244
# vsvsms92ng            IrO2/final_opt_new1-3/261_fixed.cif    AB2     261
# x2xj6wb48k            IrO2/final_opt_new1-3/323_fixed.cif    AB2     323
# cr6rcena9l            IrO2/final_opt_new1-3/339_fixed.cif    AB2     339
# nkmd71vt9q            IrO2/final_opt_new1-3/348_fixed.cif    AB2     348
# cung63bez1            IrO2/final_opt_new1-3/349_fixed.cif    AB2     349
# 7am4vwzi7p            IrO2/final_opt_new1-3/385_fixed.cif    AB2     385
# v1vpxgbg9s    April_Backup/IrO2/final_relax/388_fixed.cif    AB2     388
# bp7ynac4my            IrO2/final_opt_new1-3/432_fixed.cif    AB2     432
# b49kx4c19q    April_Backup/IrO2/final_relax/444_fixed.cif    AB2     444
# vl6uvqne6d            IrO2/final_opt_new1-3/464_fixed.cif    AB2     464
# ...                                                   ...    ...     ...
# 7h62vo74x4       IrO3/final_opt_new1-3_sorted/3_fixed.cif    AB3       3
# vwbhvwmjmw       IrO3/final_opt_new1-3_sorted/9_fixed.cif    AB3       9
# 94vpmqvh9p      IrO3/final_opt_new1-3_sorted/14_fixed.cif    AB3      14
# bpvynr7p9w      IrO3/final_opt_new1-3_sorted/38_fixed.cif    AB3      38
# nrml6dms9l      IrO3/final_opt_new1-3_sorted/45_fixed.cif    AB3      45
# 8jvfcyvk92      IrO3/final_opt_new1-3_sorted/58_fixed.cif    AB3      58
# mp7svl6j8s      IrO3/final_opt_new1-3_sorted/64_fixed.cif    AB3      64
# 8pmqmq9r8f      IrO3/final_opt_new1-3_sorted/69_fixed.cif    AB3      69
# 6s648e8s6p      IrO3/final_opt_new1-3_sorted/87_fixed.cif    AB3      87
# vlbdnoxlnh      IrO3/final_opt_new1-3_sorted/88_fixed.cif    AB3      88
# 7en56j64mi     IrO3/final_opt_new1-3_sorted/109_fixed.cif    AB3     109
# 9e8jmu7hmo     IrO3/final_opt_new1-3_sorted/112_fixed.cif    AB3     112
# 7f8pm5mhnu     IrO3/final_opt_new1-3_sorted/115_fixed.cif    AB3     115
# zr9ic2zaz5     IrO3/final_opt_new1-3_sorted/116_fixed.cif    AB3     116
# 9pzh8yxixe     IrO3/final_opt_new1-3_sorted/117_fixed.cif    AB3     117
# xjxdzi73bg     IrO3/final_opt_new1-3_sorted/128_fixed.cif    AB3     128
# 9txdvicqcf     IrO3/final_opt_new1-3_sorted/132_fixed.cif    AB3     132
# xy6kzjninu  April_Backup/IrO3/winners/relax/146_fixed.cif    AB3     146
# cgx3mkzhmd     IrO3/final_opt_new1-3_sorted/149_fixed.cif    AB3     149
# nocg9ivex1     IrO3/final_opt_new1-3_sorted/156_fixed.cif    AB3     156
# 6d6a8a637i     IrO3/final_opt_new1-3_sorted/157_fixed.cif    AB3     157
# b5cgvsb16w     IrO3/final_opt_new1-3_sorted/164_fixed.cif    AB3     164
# macixavwv3     IrO3/final_opt_new1-3_sorted/174_fixed.cif    AB3     174
# 8g6g9dv47g     IrO3/final_opt_new1-3_sorted/186_fixed.cif    AB3     186
# 8gnt9rnd92     IrO3/final_opt_new1-3_sorted/187_fixed.cif    AB3     187
# vt9ynkzyna     IrO3/final_opt_new1-3_sorted/198_fixed.cif    AB3     198
# b4nrnqvl8h     IrO3/final_opt_new1-3_sorted/215_fixed.cif    AB3     215
# 95nfmd6fce     IrO3/final_opt_new1-3_sorted/242_fixed.cif    AB3     242
# mkvpml8q9e     IrO3/final_opt_new1-3_sorted/244_fixed.cif    AB3     244
# bgcpc2vabf     IrO3/final_opt_new1-3_sorted/255_fixed.cif    AB3     255
#
#            source
# id_unique
# z39g648rnl  chris
# 82mwbwbgbl  chris
# 8495vjvsc3  chris
# xonhb1cgnq  chris
# 8aza84xlvs  chris
# vwxrnun48g  chris
# 9wzqvtmw6a  chris
# c48lx363be  chris
# 6fzy7kcrxy  chris
# ckbg7d9u6u  chris
# mpbd6sz1z5  chris
# cant6qca6o  chris
# zunqxh6g9j  chris
# 9y85x1cp6e  chris
# xgmkzuxf8g  chris
# cfcivdxrc2  chris
# mlva81bg7p  chris
# nt6wv1n27r  chris
# m4cacfvjvh  chris
# 9uxemw7rv2  chris
# vsvsms92ng  chris
# x2xj6wb48k  chris
# cr6rcena9l  chris
# nkmd71vt9q  chris
# cung63bez1  chris
# 7am4vwzi7p  chris
# v1vpxgbg9s  chris
# bp7ynac4my  chris
# b49kx4c19q  chris
# vl6uvqne6d  chris
# ...           ...
# 7h62vo74x4  chris
# vwbhvwmjmw  chris
# 94vpmqvh9p  chris
# bpvynr7p9w  chris
# nrml6dms9l  chris
# 8jvfcyvk92  chris
# mp7svl6j8s  chris
# 8pmqmq9r8f  chris
# 6s648e8s6p  chris
# vlbdnoxlnh  chris
# 7en56j64mi  chris
# 9e8jmu7hmo  chris
# 7f8pm5mhnu  chris
# zr9ic2zaz5  chris
# 9pzh8yxixe  chris
# xjxdzi73bg  chris
# 9txdvicqcf  chris
# xy6kzjninu  chris
# cgx3mkzhmd  chris
# nocg9ivex1  chris
# 6d6a8a637i  chris
# b5cgvsb16w  chris
# macixavwv3  chris
# 8g6g9dv47g  chris
# 8gnt9rnd92  chris
# vt9ynkzyna  chris
# b4nrnqvl8h  chris
# 95nfmd6fce  chris
# mkvpml8q9e  chris
# bgcpc2vabf  chris
#
# [78 rows x 10 columns]

# %%
# oqmd_ids = [
#     10054,
#     694981,
#     690788,
#     825007,
#     694982,
#     825035,
#     825034,
#     325288,
#     298609,
#     309147,
#     349774,
#     ]

# for oqmd_id in oqmd_ids:

#     unique_ids_possible = [
#         id_mapp_iro2.get(oqmd_id, None),
#         id_mapp_iro3.get(oqmd_id, None),
#         ]

#     reduced_id_list = [v for v in unique_ids_possible if v is not None]
    
#     if len(reduced_id_list) != 1:
#         print("ERROR | !!!!! | IDJFISDJF")
#     else:
#         print(reduced_id_list[0])

# %%
# df_combined_iro2 = pd.concat([df_iro2_unique, train_data_dict["iro2"]], axis=1)


# data = []

# y_array = df_combined_iro2["form_e"]
# trace = go.Scatter(
#     y=y_array,
#     mode="markers",
#     name="Mine",
#     )
# data.append(trace)

# y_array = df_combined_iro2["form_e_chris"]
# trace = go.Scatter(
#     y=y_array,
#     mode="markers",
#     name="Chris",
#     )
# data.append(trace)

# py.iplot(data,
#     filename=os.path.join(
#         "__temp__",
#         "temp_plot_0"
#         )
#     )

# %%
# print(
#     "Mean  error: ",
#     (df_combined_iro2["form_e"] - df_combined_iro2["form_e_chris"]).dropna().mean()
#     )

# %%
# df_combined_iro3 = pd.concat(
#     [df_iro3_unique, train_data_dict["iro3"]],
#     axis=1)

# data = []

# y_array = df_combined_iro3["form_e"]
# trace = go.Scatter(
#     y=y_array,
#     mode="markers",
#     name="Mine",
#     )
# data.append(trace)

# y_array = df_combined_iro3["form_e_chris"]
# trace = go.Scatter(
#     y=y_array,
#     mode="markers",
#     name="Chris",
#     )
# data.append(trace)

# py.iplot(data,
#     filename=os.path.join(
#         "__temp__",
#         "temp_plot_1"
#         )
#     )

# %%
# print(
#     "Mean  error: ",
#     (df_combined_iro3["form_e"] - df_combined_iro3["form_e_chris"]).dropna().mean()
#     )
