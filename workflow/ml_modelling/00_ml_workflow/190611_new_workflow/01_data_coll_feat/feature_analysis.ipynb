# %% [markdown]
# # Import Modules

# %%
import os
import sys

import pickle

import plotly.express as px


from plotting.my_plotly import my_plotly_plot

sys.path.insert(0, os.path.join(os.environ["PROJ_irox"], "data"))
from proj_data_irox import (
    voronoi_features_data_path,
    voronoi_features_all_data_path,
    )

# %% [markdown]
# # Import Data

# %%
with open(voronoi_features_all_data_path, "rb") as fle:
    df_voronoi = pickle.load(fle)

with open(voronoi_features_data_path, "rb") as fle:
    df_voronoi_pca = pickle.load(fle)

# %%
df_voronoi.describe()

df_voronoi.head()
# Out:
#             mean_EffectiveCoordination  var_EffectiveCoordination  \
# 95c29e9f6h                   -0.744276                  -0.423700
# 8ixs9szims                   -0.960359                  -1.886188
# be7wm39lmp                    1.779807                  -1.700557
# bynub4vic2                   -1.073808                   1.581903
# mqxi8q7kvd                   -0.883667                   1.027938
#
#             min_EffectiveCoordination  max_EffectiveCoordination  \
# 95c29e9f6h                  -0.285592                  -0.761804
# 8ixs9szims                   0.374640                  -2.068382
# be7wm39lmp                   2.154502                   0.665805
# bynub4vic2                  -1.173917                   0.445941
# mqxi8q7kvd                  -0.978565                  -0.263940
#
#             var_MeanBondLength  min_MeanBondLength  max_MeanBondLength  \
# 95c29e9f6h           -0.410454            0.440565           -0.434186
# 8ixs9szims           -1.409318            1.444274           -1.108645
# be7wm39lmp           -1.333436            1.407646           -1.034574
# bynub4vic2            1.725299           -1.600050            2.513089
# mqxi8q7kvd            1.106068           -0.984040            0.989462
#
#             mean_BondLengthVariation  var_BondLengthVariation  \
# 95c29e9f6h                 -0.629871                 0.097483
# 8ixs9szims                 -1.598983                -1.412223
# be7wm39lmp                 -1.488957                -1.409533
# bynub4vic2                  0.358821                 1.824268
# mqxi8q7kvd                  0.909230                 0.708832
#
#             min_BondLengthVariation  ...  mean_GSvolume_pa  dev_GSvolume_pa  \
# 95c29e9f6h                -0.772415  ...          0.620795         0.620795
# 8ixs9szims                -0.501601  ...          0.620795         0.620795
# be7wm39lmp                -0.387243  ...          0.620795         0.620795
# bynub4vic2                -0.847510  ...          0.620795         0.620795
# mqxi8q7kvd                 0.519878  ...          0.620795         0.620795
#
#             mean_SpaceGroupNumber  dev_SpaceGroupNumber  frac_sValence  \
# 95c29e9f6h               0.620795              0.620795      -0.620795
# 8ixs9szims               0.620795              0.620795      -0.620795
# be7wm39lmp               0.620795              0.620795      -0.620795
# bynub4vic2               0.620795              0.620795      -0.620795
# mqxi8q7kvd               0.620795              0.620795      -0.620795
#
#             frac_pValence  frac_dValence  frac_fValence  CanFormIonic  \
# 95c29e9f6h      -0.620795       0.620795       0.620795      0.620795
# 8ixs9szims      -0.620795       0.620795       0.620795      0.620795
# be7wm39lmp      -0.620795       0.620795       0.620795      0.620795
# bynub4vic2      -0.620795       0.620795       0.620795      0.620795
# mqxi8q7kvd      -0.620795       0.620795       0.620795      0.620795
#
#             MeanIonicChar
# 95c29e9f6h       0.620795
# 8ixs9szims       0.620795
# be7wm39lmp       0.620795
# bynub4vic2       0.620795
# mqxi8q7kvd       0.620795
#
# [5 rows x 129 columns]

# %%
df_voronoi_pca.describe()
# Out:
#                PCA0          PCA1          PCA2          PCA3          PCA4  \
# count  9.670000e+02  9.670000e+02  9.670000e+02  9.670000e+02  9.670000e+02
# mean  -6.466159e-16 -4.408745e-17  7.795671e-17  1.487951e-16 -2.910461e-17
# std    8.043522e+00  6.042506e+00  3.966198e+00  2.228110e+00  1.649307e+00
# min   -1.329291e+01 -1.819031e+01 -5.312946e+00 -4.717010e+00 -4.270607e+00
# 25%   -7.066171e+00 -3.945255e+00 -2.868178e+00 -1.414049e+00 -1.075292e+00
# 50%   -2.595930e+00 -4.696189e-01 -6.863710e-01 -4.654051e-01 -2.707961e-01
# 75%    7.968736e+00  3.143308e+00  1.323511e+00  6.049402e-01  7.242788e-01
# max    1.814351e+01  1.825233e+01  3.242639e+01  1.079556e+01  6.524879e+00
#
#                PCA5          PCA6          PCA7          PCA8          PCA9  \
# count  9.670000e+02  9.670000e+02  9.670000e+02  9.670000e+02  9.670000e+02
# mean   6.521269e-17  1.419065e-16 -1.917345e-17 -1.016078e-16 -1.196905e-17
# std    1.194864e+00  9.873195e-01  8.375917e-01  5.799416e-01  5.682052e-01
# min   -4.658551e+00 -3.375285e+00 -3.219165e+00 -3.045001e+00 -2.464441e+00
# 25%   -6.793134e-01 -5.842520e-01 -5.095359e-01 -3.338275e-01 -2.890082e-01
# 50%    9.640349e-02  2.411729e-02 -8.989167e-02 -1.903992e-03 -1.004735e-02
# 75%    7.210613e-01  5.992767e-01  5.003467e-01  3.003009e-01  2.680753e-01
# max    5.295155e+00  6.153211e+00  5.537999e+00  3.924756e+00  3.896747e+00
#
#               PCA10         PCA11         PCA12         PCA13         PCA14  \
# count  9.670000e+02  9.670000e+02  9.670000e+02  9.670000e+02  9.670000e+02
# mean  -2.485660e-17  1.392658e-16  5.987397e-17 -4.850768e-17  9.040654e-17
# std    4.994693e-01  4.135348e-01  3.268755e-01  2.403869e-01  2.132120e-01
# min   -3.184081e+00 -2.284701e+00 -1.912899e+00 -9.202605e-01 -1.093658e+00
# 25%   -1.996647e-01 -1.794557e-01 -1.771412e-01 -1.263197e-01 -1.073063e-01
# 50%   -3.209602e-02  1.908747e-02  3.855769e-02 -1.268448e-02 -1.670988e-02
# 75%    1.510093e-01  2.443276e-01  1.781122e-01  1.173723e-01  9.969080e-02
# max    5.013815e+00  2.290555e+00  2.204971e+00  1.192451e+00  1.407144e+00
#
#               PCA15         PCA16         PCA17         PCA18         PCA19
# count  9.670000e+02  9.670000e+02  9.670000e+02  9.670000e+02  9.670000e+02
# mean   1.896105e-16  4.316896e-17 -8.110326e-17 -9.232245e-17  2.588317e-17
# std    2.017233e-01  1.499424e-01  1.412855e-01  1.188126e-01  1.092533e-01
# min   -9.203101e-01 -8.549982e-01 -6.920463e-01 -4.972753e-01 -6.581139e-01
# 25%   -9.204534e-02 -6.639018e-02 -7.915980e-02 -5.511808e-02 -6.158913e-02
# 50%   -9.582880e-04 -4.829690e-04 -5.546405e-03 -3.543860e-03 -7.189159e-03
# 75%    1.013683e-01  6.016083e-02  7.223221e-02  4.243601e-02  6.755784e-02
# max    1.333662e+00  1.727253e+00  7.726300e-01  8.979395e-01  6.632793e-01

# %%
# df_i = df_voronoi_pca

# fig = px.scatter_matrix(df_i)
# fig.show()

# fig.layout["height"] = 1200
# fig = my_plotly_plot(figure=fig, plot_name="scatter_matrix_tmp")

# %%
# df_i = df_voronoi

# fig = px.scatter_matrix(df_i)
# fig.show()

# fig.layout["height"] = 1200
# fig = my_plotly_plot(figure=fig, plot_name="scatter_matrix_voronoi_full")
