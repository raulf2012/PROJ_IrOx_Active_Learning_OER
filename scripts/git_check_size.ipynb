# %%
import os
print(os.getcwd())
import sys

import pandas as pd
# Out:
# /mnt/f/Dropbox/01_norskov/00_git_repos/PROJ_IrOx_Active_Learning_OER/scripts

# %%
os.chdir(
    os.environ["PROJ_irox"]
    )

# %%
import subprocess
res = subprocess.check_output(
    ["git", "ls-files", "--others", "--exclude-standard"]
    )

data_dict_list = []
for path_i in res.splitlines():
    data_dict_i = dict()

    path_i = path_i.decode('UTF-8')
    data_dict_i["path"] = path_i

    file_name_i = path_i.split("/")[-1]
    data_dict_i["file"] = file_name_i

    size_i = os.stat(path_i).st_size / 1000  # Size in KB
    data_dict_i["size_kb"] = size_i
    
    data_dict_list.append(data_dict_i)
    
df = pd.DataFrame(data_dict_list)

# %%
df["size_mb"] = df.size_kb / 1000


df = df.sort_values("size_kb", ascending=False)

df.iloc[0:20]
# Out:
#                                                  path  \
# 9        parse_dft_data/jobs_bin/job_dataframe.pickle
# 26             workflow/02_oer_analysis/oer_table.svg
# 57  workflow/ml_modelling/00_ml_workflow/al_plots_...
# 72  workflow/ml_modelling/00_ml_workflow/performan...
# 4   __misc__/00_181207_random_old_irox_figures/con...
# 3   __misc__/00_181207_random_old_irox_figures/con...
# 5   __misc__/00_181207_random_old_irox_figures/oer...
# 2   __misc__/00_181207_random_old_irox_figures/con...
# 6   __misc__/00_181207_random_old_irox_figures/sur...
# 1   __misc__/00_181207_random_old_irox_figures/bul...
# 38             workflow/an_data_processing_test.ipynb
# 58  workflow/ml_modelling/00_ml_workflow/combined_...
# 28  workflow/03_combined_oer_surf_e/an_surface-ene...
# 71  workflow/ml_modelling/00_ml_workflow/performan...
# 15      python_classes/dev_new_al_class/sandbox.ipynb
# 70  workflow/ml_modelling/00_ml_workflow/performan...
# 75  workflow/ml_modelling/energy_vs_volume/00_main...
# 53    workflow/ml_modelling/00_ml_workflow/al_data.py
# 86  workflow/ml_modelling/opt_mae_err_gp_model/cv_...
# 16  python_classes/dev_new_al_class/serial_vs_para...
#
#                                     file   size_kb   size_mb
# 9                   job_dataframe.pickle  4612.111  4.612111
# 26                         oer_table.svg   412.586  0.412586
# 57                     viridis_color.svg   352.558  0.352558
# 72              effect_of_num_of_sys.odp   233.509  0.233509
# 4            convergence_plot_iro3_0.png   178.258  0.178258
# 3            convergence_plot_iro2_1.png   119.050  0.119050
# 5                        oer_volcano.png   104.476  0.104476
# 2            convergence_plot_iro2_0.png    83.912  0.083912
# 6            surface_energy_pourbaix.png    79.540  0.079540
# 1                    bulk_pourbaix_0.png    75.537  0.075537
# 38         an_data_processing_test.ipynb    43.458  0.043458
# 58             create_subplots__v5.ipynb    41.238  0.041238
# 28  an_surface-energy_pourbaix__v4.ipynb    37.011  0.037011
# 71             comp_perf_plots__v2.ipynb    35.396  0.035396
# 15                         sandbox.ipynb    33.006  0.033006
# 70                   plot_all_runs.ipynb    29.450  0.029450
# 75             00_plotting_kirsten.ipynb    24.018  0.024018
# 53                            al_data.py    23.025  0.023025
# 86                    cv_error__v3.ipynb    20.300  0.020300
# 16       serial_vs_parallel_scaling.xlsx    20.164  0.020164
