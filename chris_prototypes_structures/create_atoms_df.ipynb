# %% [markdown]
# # Parse Atoms Objects for IrO2 and IrO3 Unique Prototypes
# ---

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

import pickle

from ase import io
from ase.visualize import view
import pandas as pd


import bulk_enumerator as be
import time

from pymatgen.io.vasp.inputs import Poscar
from pymatgen.io.ase import AseAtomsAdaptor

# pd.set_option('display.max_rows', None)

# %% [markdown]
# # Script Inputs

# %%
tmp = 42

# %% [markdown]
# # Reading Structures

# %%
root_path = os.path.join(
    os.environ["PROJ_irox"],
    "chris_prototypes_structures",
    )

master_list = []
for root, dirs, files in os.walk(root_path):
    if ".ipynb_checkpoints" in root:
        continue

    if "iro2" in root:
        stoich_i = "AB2"
    elif "iro3" in root:
        stoich_i = "AB3"
    else:
        stoich_i = None

    if "oqmd" in root:
        source_i = "oqmd"
    else:
        source_i = "chris"

    for file_i in files:
        if ".POSCAR" in file_i or ".cif" in file_i:
            id_i = file_i.split("_")[0]

            path_i = root.replace("/mnt/c/Users/raulf/Dropbox/01_norskov/00_projects/", "")

            atoms_i = io.read(
                os.path.join(root, file_i))

            sys_i = {
                "id_old": int(id_i),
                "atoms": atoms_i,
                "stoich": stoich_i,
                "path": path_i,
                "source": source_i,
                }
            master_list.append(sys_i)

df_struct = pd.DataFrame(master_list)

# %% [markdown]
# # Setting Unique ID Tag

# %%
path_i = os.path.join(
    os.environ["PROJ_irox"],
    "data/ml_irox_data",
    "unique_ids.csv")
df_id = pd.read_csv(path_i)


id_mapp_iro2 = dict(zip(
    df_id[df_id["stoich"] == "AB2"]["id"],
    df_id[df_id["stoich"] == "AB2"]["unique_ids"]))

id_mapp_iro3 = dict(zip(
    df_id[df_id["stoich"] == "AB3"]["id"],
    df_id[df_id["stoich"] == "AB3"]["unique_ids"]))

# %%
def method(row_i):
    id_i = row_i["id_old"]

    if row_i["stoich"] == "AB2":
        unique_id_i = id_mapp_iro2[id_i]
    elif row_i["stoich"] == "AB3":
        unique_id_i = id_mapp_iro3[id_i]
    else:
        print("BADDDDD!!!!! fsdfjisajids")
        unique_id_i = None

    return(unique_id_i)

df_struct["id_unique"] = df_struct.apply(
    method,
    axis=1,
    )

df_struct.set_index("id_unique", inplace=True)

# %% [markdown]
# # Analyzing Structures with Bulk Enumerator

# %%
t0 = time.time()

data_list = []
for id_i, row_i in df_struct.iterrows():   
    atoms_i = row_i["atoms"]

    structure_i = AseAtomsAdaptor.get_structure(atoms_i)
    poscar_str_i = Poscar(structure_i).get_string()

    b = be.bulk.BULK()
    b.set_structure_from_file(poscar_str_i)

    spacegroup_i = b.get_spacegroup()
    species_i = b.get_species()
    wyckoff_i = b.get_wyckoff()
    name_i = b.get_name()
    parameter_values_i = b.get_parameter_values()

    row_dict_i = {
        "id": id_i,
        "spacegroup_i": spacegroup_i,
        "species_i": species_i,
        "wyckoff_i": wyckoff_i,
        "name_i": name_i,
        "parameter_values_i": parameter_values_i,
        }
    data_list.append(row_dict_i)


t1 = time.time()
print("time to complete for loop: ")
print(t1 - t0)

df_proto = pd.DataFrame(data_list)
df_proto.set_index("id", inplace=True)

print(len(df_proto["name_i"].to_list()))

print(len(
    set(df_proto["name_i"].to_list())
    ))
# Out:
# time to complete for loop:
# 159.689435005188
# 967
# 942

# %% [markdown]
# # Save data to pickle

# %%
with open("data_structures.pickle", "wb") as fle:
    pickle.dump(df_struct, fle)

with open("data_prototypes.pickle", "wb") as fle:
    pickle.dump(df_proto, fle)

# %%
df_struct
# Out:
#                                                         atoms  id_old  \
# id_unique
# 95c29e9f6h  (Atom('O', [0.0, 0.0, 1.8684114399999998], tag...       0
# 8ixs9szims  (Atom('O', [0.0, 0.0, 1.413785], tag=0, index=...     100
# be7wm39lmp  (Atom('O', [6.6350561574, 3.5561670516, 1.1026...     101
# bynub4vic2  (Atom('O', [9.828870512, 10.196679652, 0.0], t...     102
# mqxi8q7kvd  (Atom('O', [9.0657, 11.106933011999999, 0.0], ...     103
# 81meck64ba  (Atom('O', [0.0, 4.2656295, 9.564676192], tag=...     104
# 7fvk74mhcj  (Atom('O', [11.94255, 5.6734275, 0.0], tag=0, ...     105
# zon4z3vpvd  (Atom('O', [15.380149139, 1.4932307459999998, ...     106
# c48lx363be  (Atom('Ir', [0.0, 0.0, 0.0], tag=0, index=0), ...     107
# vhbaxp9wmh  (Atom('O', [2.428007823, 3.72765, 9.73096929],...     108
# bovtbhmf6p  (Atom('O', [11.066691160000001, 23.624025125, ...     109
# crnonhbf6j  (Atom('Ir', [-2.3764899999223488e-05, 3.129046...      10
# 7ln2nfzp7q  (Atom('O', [26.104481279999998, 26.10448127999...     110
# 8qzamrb4m2  (Atom('Ir', [0.0, 0.0, 4.303467411200001], tag...     111
# vt658pbemi  (Atom('Ir', [0.0, 0.0, 0.0], tag=0, index=0), ...     112
# zd64ms9gm2  (Atom('Ir', [0.0, 0.0, 1.743597309], tag=0, in...     113
# 9qztzg84nh  (Atom('O', [1.9503975, 4.453946832, 1.1327225]...     114
# 846ynybu75  (Atom('O', [-1.6032529342999988, 4.62826661854...     115
# 8hzf7ecw84  (Atom('Ir', [7.5043777380000005, 11.2522031490...     116
# xgz4728r7f  (Atom('O', [16.89040066, 8.14116506, 13.694079...     117
# xoxjmq6j91  (Atom('O', [2.7331521202307845, 7.8913062974, ...     118
# bkxunev3v5  (Atom('O', [2.024229058332918, 5.506005, 1.542...     119
# baxf8p7emk  (Atom('O', [0.7526120184, 5.886259739100001, 0...      11
# 8hzkzt7lnq  (Atom('O', [6.03545, 6.65337194, 16.26086885],...     120
# 8fze8rxf8w  (Atom('O', [22.527479137694613, 8.877986325, 8...     121
# z3ngxhbrz4  (Atom('O', [1.82406847, 0.0, 0.0], tag=0, inde...     122
# cf9lbhvjmq  (Atom('O', [2.543405, 3.5540368042000003, 7.11...     123
# vr9rxdnhcr  (Atom('Ir', [3.3653400000499545e-05, 2.1093750...     124
# cy92vdcuc2  (Atom('O', [12.833504406, 12.931617056999999, ...     125
# nh8tmr7yxt  (Atom('O', [0.0, 0.0, 0.0], tag=0, index=0), A...     126
# ...                                                       ...     ...
# 7h7yns937p  (Atom('Ir', [2.4305951867106264, 4.19375249999...      83
# 7y92xqcoby  (Atom('O', [2.613381467200001, 1.5819073777898...      84
# bt8r6jz26o  (Atom('Ir', [1.4040182882, 1.4040182882, 1.404...      85
# xfndvkclnp  (Atom('Ir', [-3.201129999919061e-05, 3.6963650...      86
# 6s648e8s6p  (Atom('O', [3.094404104, 7.546235529, 13.59806...      87
# vlbdnoxlnh  (Atom('O', [-0.2398912467321327, 7.94841990060...      88
# 6tvo819y9e  (Atom('O', [8.355038709808758, 0.84006, 6.5590...      89
# b5757fmaxd  (Atom('O', [0.0, 0.0, 0.0], tag=0, index=0), A...       8
# zdvt8a8f7j  (Atom('Ir', [2.8236280906238287, 0.0, 3.715128...      90
# 64vo6w8wvq  (Atom('O', [8.170318774922793, 1.802725, 1.171...      91
# 7e6fm2ci7f  (Atom('Ir', [0.0, 0.0, 0.0], tag=0, index=0), ...      92
# bwzk8k6rb4  (Atom('Ir', [3.0048781764, 0.0, 1.829795], tag...      93
# b1mh6qmj62  (Atom('Ir', [2.2991247908171557, 1.59071548762...      94
# xlbfb49wml  (Atom('O', [1.7516784176808566, 9.20206188, 4....      95
# 9sx5z4m1x1  (Atom('Ir', [0.0, 0.0, 0.0], tag=0, index=0), ...      96
# 9i6ixublcr  (Atom('O', [1.977694054, 0.0, 0.0], tag=0, ind...      97
# cqbrnhbacg  (Atom('Ir', [3.9839090021177945, 2.09145, 6.29...      98
# x2vtvkcezt  (Atom('O', [1.4725766859000007, 2.555899802335...      99
# vwbhvwmjmw  (Atom('O', [11.199985319, 8.08498346, 5.499488...       9
# v4zonyzw7d  (Atom('Ir', [0.0, 0.0, 0.0], index=0), Atom('I...   10054
# v1bebhmeny  (Atom('Ir', [0.0, 0.0, 0.0], index=0), Atom('I...  298609
# vjvfzpb48y  (Atom('Ir', [3.329873, 0.0, 0.0], index=0), At...  309147
# 6svsc4bqxh  (Atom('Ir', [2.4936750002493673, 1.43972399985...  325288
# x4zsxdmanr  (Atom('Ir', [0.0, 0.0, 0.0], index=0), Atom('O...  349774
# 826imfvjm5  (Atom('Ir', [0.0, 1.4622067633803217, 0.0], in...  690788
# x5xfz16h95  (Atom('Ir', [-2.6049721607001235, 3.0090097395...  694981
# nl9gb2csx5  (Atom('Ir', [-2.6049721607001235, 3.0090097395...  694982
# 65xlxp7o8i  (Atom('Ir', [2.604961839299876, 3.009009739595...  825007
# nu64ni7a6i  (Atom('Ir', [2.604961839299876, 3.009009739595...  825034
# z17s6dzu6r  (Atom('Ir', [2.604961839299876, 3.009009739595...  825035
#
#                                                          path source stoich
# id_unique
# 95c29e9f6h  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# 8ixs9szims  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# be7wm39lmp  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# bynub4vic2  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# mqxi8q7kvd  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# 81meck64ba  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# 7fvk74mhcj  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# zon4z3vpvd  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# c48lx363be  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# vhbaxp9wmh  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# bovtbhmf6p  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# crnonhbf6j  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# 7ln2nfzp7q  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# 8qzamrb4m2  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# vt658pbemi  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# zd64ms9gm2  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# 9qztzg84nh  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# 846ynybu75  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# 8hzf7ecw84  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# xgz4728r7f  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# xoxjmq6j91  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# bkxunev3v5  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# baxf8p7emk  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# 8hzkzt7lnq  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# 8fze8rxf8w  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# z3ngxhbrz4  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# cf9lbhvjmq  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# vr9rxdnhcr  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# cy92vdcuc2  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# nh8tmr7yxt  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB2
# ...                                                       ...    ...    ...
# 7h7yns937p  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# 7y92xqcoby  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# bt8r6jz26o  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# xfndvkclnp  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# 6s648e8s6p  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# vlbdnoxlnh  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# 6tvo819y9e  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# b5757fmaxd  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# zdvt8a8f7j  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# 64vo6w8wvq  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# 7e6fm2ci7f  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# bwzk8k6rb4  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# b1mh6qmj62  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# xlbfb49wml  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# 9sx5z4m1x1  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# 9i6ixublcr  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# cqbrnhbacg  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# x2vtvkcezt  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# vwbhvwmjmw  04_irox_surfaces_oer/chris_prototypes_structur...  chris    AB3
# v4zonyzw7d  04_irox_surfaces_oer/chris_prototypes_structur...   oqmd    AB2
# v1bebhmeny  04_irox_surfaces_oer/chris_prototypes_structur...   oqmd    AB3
# vjvfzpb48y  04_irox_surfaces_oer/chris_prototypes_structur...   oqmd    AB3
# 6svsc4bqxh  04_irox_surfaces_oer/chris_prototypes_structur...   oqmd    AB3
# x4zsxdmanr  04_irox_surfaces_oer/chris_prototypes_structur...   oqmd    AB3
# 826imfvjm5  04_irox_surfaces_oer/chris_prototypes_structur...   oqmd    AB3
# x5xfz16h95  04_irox_surfaces_oer/chris_prototypes_structur...   oqmd    AB3
# nl9gb2csx5  04_irox_surfaces_oer/chris_prototypes_structur...   oqmd    AB3
# 65xlxp7o8i  04_irox_surfaces_oer/chris_prototypes_structur...   oqmd    AB3
# nu64ni7a6i  04_irox_surfaces_oer/chris_prototypes_structur...   oqmd    AB3
# z17s6dzu6r  04_irox_surfaces_oer/chris_prototypes_structur...   oqmd    AB3
#
# [967 rows x 5 columns]

# %%
# from random import choice

# def GetFriendlyID():
#     """
#     Create an ID string we can recognise.
#     (Think Italian or Japanese or Native American.)
#     """
#     v = 'qwertyuiopasdfghjkl12345'
#     c = 'zxcvbnm6789'
    
#     return ''.join([choice(v if i%2 else c) for i in range(10)])

# def GetUniqueFriendlyID(used_ids):
#     """
#     Return an ID that is not in our list of already used IDs.
#     """
#     # trying infinitely is a bad idea
#     LIMIT = 1000

#     count = 0
#     while count < LIMIT:
#         id = GetFriendlyID()
#         if id not in used_ids:
#             break
#         count += 1
#         id = ''
#     return id

# used_ids = set()
# for i in range(len(df_struct)):
#     id = GetUniqueFriendlyID(used_ids)
#     if not id:
#         print('something broke')
#         break
#     used_ids.add(id)

# df_struct.index = used_ids
